# %% [markdown]
# # Learning sampling pattern
# First version of the full algorithm:
# - Only one square image
# - Learning points and not shots

# %%
from mri.operators import NonCartesianFFT, WaveletUD2, WaveletN
import pysap
from pysap.data import get_sample_data
from mri.operators.utils import convert_mask_to_locations, convert_locations_to_mask
from modopt.math.metrics import ssim
import matplotlib.pyplot as plt
import numpy as np
# Out:
#                  .|'''|       /.\      '||'''|,
#                  ||          // \\      ||   ||
# '||''|, '||  ||` `|'''|,    //...\\     ||...|'
#  ||  ||  `|..||   .   ||   //     \\    ||
#  ||..|'      ||   |...|' .//       \\. .||
#  ||       ,  |'
# .||        ''
#
# Package version: 0.0.3
#
# License: CeCILL-B
#
# Authors:
#
# Antoine Grigis <antoine.grigis@cea.fr>
# Samuel Farrens <samuel.farrens@cea.fr>
# Jean-Luc Starck <jl.stark@cea.fr>
# Philippe Ciuciu <philippe.ciuciu@cea.fr>
#
# Dependencies:
#
# scipy          : >=1.3.0   - required | 1.3.0     installed
# numpy          : >=1.16.4  - required | 1.16.4    installed
# matplotlib     : >=3.0.0   - required | 3.1.1     installed
# astropy        : >=3.0.0   - required | 3.2.1     installed
# nibabel        : >=2.3.2   - required | 2.5.1     installed
# pyqtgraph      : >=0.10.0  - required | 0.10.0    installed
# progressbar2   : >=3.34.3  - required | ?         installed
# modopt         : >=1.4.0   - required | 1.4.1     installed
# scikit-learn   : >=0.19.1  - required | ?         installed
# pywt           : >=1.0.0   - required | 1.0.3     installed
# pysparse       : >=0.0.1   - required | 0.1.0     installed

# %%
# Lower level imports
from LowerLevel.prox import prox_G,prox_F1_dual,prox_F2_dual
from LowerLevel.pdhg import pdhg
from LowerLevel.cost_utils import *

#Upper level imports
from scipy.sparse.linalg import cg,LinearOperator
import scipy
import time
from UpperLevel.L1norm import *
from UpperLevel.hessians import *
from scipy.optimize.lbfgsb import fmin_l_bfgs_b
from scipy.stats import norm

# %%
u0 = get_sample_data('2d-mri')
n=40
u0_mat = (1+0j)*u0.data[125:125+n,125:125+n]

# %%
x = np.linspace(0,n,n,endpoint=False)/n-0.5
y = np.linspace(0,n,n,endpoint=False)/n-0.5
X,Y = np.meshgrid(x,y)
kspace_loc = np.stack([X.flatten('F'),Y.flatten('F')],axis=1)

m = convert_locations_to_mask(kspace_loc,(n,n))
fourier_op = NonCartesianFFT(samples=kspace_loc, shape=(n,n),implementation='cpu')
# Out:
# /home/guillaume/temp/pysap-mri/mri/operators/fourier/utils.py:78: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   mask[test] = 1

# %% [markdown]
# ### Creation of cartesian mask

# %%
x = np.linspace( -0.5, 0.5, n, endpoint = False )
p = np.array([norm.pdf(u,loc=0,scale=0.15) for u in x])
p /= np.sum(p)
y_sampled = np.random.choice( x, size=int(0.7*n), p=p, replace=False)#, p=p

# %%
cartesian_p = np.zeros(n**2+1)
for y in y_sampled:
    j=int((y+0.5)*n)
    cartesian_p[j*n:(j+1)*n] = np.ones((n,))
pysap.Image(data=np.reshape(cartesian_p[:-1],(n,n))).show()

# %%
#Wavelet
linear_op = WaveletN(wavelet_name="sym8",nb_scale=1,padding_mode = "periodization")
#linear_op = WaveletUD2(wavelet_id=24,nb_scale=3)

param = {"pn1":p[-1],"epsilon":1e-1,"gamma":1e-10}
y = (1+0j)*fourier_op.op(u0_mat)+5e-7*np.random.randn(2*n*n).view(np.complex128)

# %%
print(ssim(fourier_op.adj_op(cartesian_p[:-1]*y),u0_mat))
pysap.Image(data=np.abs(u0_mat)).show()
# Out:
# 0.9234357997230107

# %% [markdown]
# ## Loss function and penalty

# %%
c = 1e10
def L(u,u2):return c/2 * np.linalg.norm(u.flatten()-u2.flatten())**2
def grad_L(u,u2):return c*(u-u2)


beta = 1e-11*c
def P(p):return beta*np.sum(p[:-1]*(2-p[:-1]))
def grad_P(p):
    Dp = np.zeros(n**2+1)
    Dp[:-1] = 2*beta*(1-p[:-1])
    return Dp

# %%
param["pn1"]=5e-7
p = cartesian_p
uk,norms,energy = pdhg(y,p[:-1],fourier_op,linear_op,param,maxit=50,verbose=0)
print(f"\nL(u(p))={L(uk,u0_mat)}\nP(p)={P(p)}")
# Out:
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# /home/guillaume/pysap-mri/Learning Sampling Pattern/LowerLevel/prox.py:17: RuntimeWarning: invalid value encountered in sqrt
#   x/np.abs(x)*(gamma+gamma**2/2/c-gamma/c*np.sqrt((c+0.5*gamma)**2-c*np.abs(x))))
# Finished in 0.4197397232055664 seconds.
#
# L(u(p))=5.151713729641647
# P(p)=111.99999999999999

# %% [markdown]
# # Upper level energy

# %%
def E(pk,**kwargs):
    print("\nEvaluating E(p)")
    # Getting parameters
    uk = kwargs.get("uk",None)       

    #Computing E(p)
    if uk is None:
        print("\nStarting PDHG")
        param["pn1"]=pk[-1]
        uk,_ = pdhg(y,pk[:-1],fourier_op,linear_op,param,compute_energy=False,maxit=50,verbose=0)
    
    return L(uk,u0_mat)+P(pk)

# %%
E(cartesian_p)
# Out:
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# /home/guillaume/pysap-mri/Learning Sampling Pattern/LowerLevel/prox.py:17: RuntimeWarning: divide by zero encountered in double_scalars
#   x/np.abs(x)*(gamma+gamma**2/2/c-gamma/c*np.sqrt((c+0.5*gamma)**2-c*np.abs(x))))
# /home/guillaume/pysap-mri/Learning Sampling Pattern/LowerLevel/prox.py:17: RuntimeWarning: invalid value encountered in subtract
#   x/np.abs(x)*(gamma+gamma**2/2/c-gamma/c*np.sqrt((c+0.5*gamma)**2-c*np.abs(x))))
# Finished in 0.2602653503417969 seconds.
# 117.07990262520815

# %%
def grad_E(pk,**kwargs):
    # -- Getting parameters
    max_cgiter = kwargs.get("max_cgiter",5000)
    cgtol = kwargs.get("cgtol",1e-6)
    compute_conv = kwargs.get("compute_conv",False)
    uk = kwargs.get("uk",None)
    cg_conv = []
    
    
    # -- Compute uk from pk with lower level solver if not given
    if uk is None:
        print("\nStarting PDHG")
        param["pn1"]=pk[-1]
        uk,_ = pdhg(y,pk[:-1],fourier_op,linear_op,param,compute_energy=False,maxit=50,verbose=0)
    
    # -- Defining linear operator from pk and uk
    def mv(w):
        w_complex = np.reshape( w[:n**2]+1j*w[n**2:] , (n,n) )
        fx = np.reshape(Du2_Etot( uk , pk , w_complex ,
                                   eps=param["epsilon"],
                                   fourier_op=fourier_op,
                                   y=y,
                                   linear_op=linear_op,
                                   gamma=param["gamma"]),(n**2,))
        return np.concatenate([np.real(fx),np.imag(fx)])
    lin = LinearOperator((2*n**2,2*n**2),matvec=mv)


    print("\nStarting Conjugate Gradient method")
    t1=time.time()
    B = np.reshape(grad_L(uk,u0_mat),(n**2,))
    B_real = np.concatenate([np.real(B),np.imag(B)])
    def cgcall(x):
        #CG callback function to plot convergence
        if compute_conv:cg_conv.append(np.linalg.norm(lin(x)-B_real)/np.linalg.norm(B_real))
    
    x_inter,convergence = scipy.sparse.linalg.cg(lin,B_real,tol=cgtol,maxiter=max_cgiter,callback=cgcall)
    print(f"Finished in {time.time()-t1}s - ||Ax-b||/||b||: {np.linalg.norm(lin(x_inter)-B_real)/np.linalg.norm(B_real)}")

    gradE = -Dpu_Etot(uk,pk,np.reshape( x_inter[:n**2]+1j*x_inter[n**2:] , (n,n) ),
                               eps=param["epsilon"],
                               fourier_op=fourier_op,
                               y=y,
                               linear_op=linear_op,
                               gamma=param["gamma"])
    
    # -- Apply DpuE
    gradE += grad_P(pk)
    
    if compute_conv:return gradE,cg_conv
    else:return gradE

# %%
#Checking if conjugate gradient converges
cgconv = []
#p=0.7*cartesian_p+0.3*np.random.rand(n**2+1)
p = np.random.rand(n**2+1)

param["epsilon"] = 1e1
param["pn1"]=1e-6
p[-1]=1e-6
print( p[ -1 ] )
gP, cg_conv = grad_E(p,max_cgiter=5000,cgtol=1e-8, compute_conv = True)
# Out:
# 1e-06
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.2091052532196045 seconds.
#
# Starting Conjugate Gradient method
# Finished in 1.6354198455810547s - ||Ax-b||/||b||: 6.015402262268623e-09

# %%
plt.plot(cg_conv)
plt.yscale("log")
plt.title("Convergence of the conjugate gradient")
plt.xlabel("Number of iterations")
plt.ylabel("||Ax-b||/||b||")
#plt.savefig("Upper Level/CG_conv.png")
# Out:
# Text(0, 0.5, '||Ax-b||/||b||')

# %%
# Checking gradE
#ptest = np.random.rand(n**2+1)
ptest = 0.5*cartesian_p+0.5*np.random.rand(n**2+1)
ptest[-1]=1e-6

param["epsilon"] = 1e2
param["pn1"] = ptest[-1]
ukptest,_ = pdhg(y,ptest[:-1],fourier_op,linear_op,param,compute_energy=False,maxit=50,verbose=0)
Eptest,gradEptest = E(ptest,uk=ukptest),grad_E(ptest,uk=ukptest)

p1 = np.random.rand(n**2+1)
p1[-1] = 1e-6
tests = np.logspace(-10,0,30)
real_values = np.array([E(ptest+t*p1) for t in tests])
approx = np.array([Eptest+np.sum(gradEptest*t*p1) for t in tests])
# Out:
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.15050411224365234 seconds.
#
# Evaluating E(p)
#
# Starting Conjugate Gradient method
# Finished in 0.35747599601745605s - ||Ax-b||/||b||: 9.18933273500147e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.09972071647644043 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.14201688766479492 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10373306274414062 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11533427238464355 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10042023658752441 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.12255454063415527 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10166549682617188 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11157035827636719 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10028815269470215 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11258578300476074 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.09999203681945801 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1138465404510498 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10035991668701172 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11221885681152344 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10121273994445801 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11358261108398438 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10043072700500488 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1130213737487793 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1013023853302002 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.12518668174743652 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10100936889648438 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11282610893249512 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10018396377563477 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11391448974609375 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10104823112487793 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11387228965759277 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.09989047050476074 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11095643043518066 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.10018205642700195 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.11428523063659668 seconds.

# %%
print(Eptest)
plt.plot(tests,abs((real_values-approx))/tests)
plt.xscale("log")
plt.yscale("log")
# Out:
# 634.4945804429877

# %% [markdown]
# # L-BFGS-B

# %%
p0 = np.random.rand(n**2+1)
#p0=0.5*cartesian_p+0.5*np.random.rand(n**2+1)
#p0=np.ones(n**2+1)
p0[-1] = 1e-7
param["epsilon"] = 1e-1

# Callback function
niter = 0
energy_upper = [E(p0)]
alphas = [p0[-1]]
def fcall(x):
    global uk,niter
    niter += 1
    Ep = E(x)
    energy_upper.append(Ep)
    alphas.append(x[-1])
    print("\033[1m" + f"\n{niter} iterations: E(p)={Ep}, alpha={x[-1]}\n\n" + "\033[0m")
# Out:
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.19347167015075684 seconds.

# %%
niter = 0
energy_upper = [E(p0)]
alphas = [p0[-1]]
pf,Emin,info = fmin_l_bfgs_b(E,p0,grad_E,bounds=[(0,1)]*n**2+[(1e-10,np.inf)],pgtol=1e-15,
                             maxfun=10,maxiter=20,
                             callback = fcall)
# Out:
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18211126327514648 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18330049514770508 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16299772262573242 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.8417220115661621s - ||Ax-b||/||b||: 9.993968068030664e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1601550579071045 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17744779586791992 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.6079864501953125s - ||Ax-b||/||b||: 8.371515257026683e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16151213645935059 seconds.
#
# 1 iterations: E(p)=169.15362320016388, alpha=8.045915764275865e-08
#
#
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17209792137145996 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16119170188903809 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.09762001037597656s - ||Ax-b||/||b||: 9.881627569487922e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16072535514831543 seconds.
#
# 2 iterations: E(p)=121.40216347972225, alpha=1e-10
#
#
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17274975776672363 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16026663780212402 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.10184192657470703s - ||Ax-b||/||b||: 6.334221917127589e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1607217788696289 seconds.
#
# 3 iterations: E(p)=110.08206952131997, alpha=1e-10
#
#
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17267060279846191 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16093730926513672 seconds.
#
# Starting Conjugate Gradient method
# Finished in 10.420134782791138s - ||Ax-b||/||b||: 9.837621226841507e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.2370471954345703 seconds.
#
# 4 iterations: E(p)=98.21370376973996, alpha=9.24378287556128e-07
#
#
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16208386421203613 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1771681308746338 seconds.
#
# Starting Conjugate Gradient method
# Finished in 8.114275693893433s - ||Ax-b||/||b||: 9.156656088640253e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.24091649055480957 seconds.
#
# 5 iterations: E(p)=97.2291265780734, alpha=6.076385698995126e-07
#
#
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.2422924041748047 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.21401476860046387 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.2648983001708984s - ||Ax-b||/||b||: 9.245234573050801e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17658042907714844 seconds.
#
# 6 iterations: E(p)=96.37969643419477, alpha=1.631004783801487e-07
#
#
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1840517520904541 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16247248649597168 seconds.
#
# Starting Conjugate Gradient method
# Finished in 4.623515844345093s - ||Ax-b||/||b||: 6.99420343514354e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18597006797790527 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.2504603862762451 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.475691556930542s - ||Ax-b||/||b||: 8.115495605726589e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.2069239616394043 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.24705815315246582 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.211817741394043s - ||Ax-b||/||b||: 8.255603809221009e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16274404525756836 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1814110279083252 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.1070430278778076s - ||Ax-b||/||b||: 8.459368707749889e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1618022918701172 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.19138336181640625 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.1307287216186523s - ||Ax-b||/||b||: 7.975482847729611e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16386938095092773 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.2076127529144287 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.132575511932373s - ||Ax-b||/||b||: 5.992640203525245e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16089582443237305 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18317341804504395 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0315539836883545s - ||Ax-b||/||b||: 8.938224640836625e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1607069969177246 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18344521522521973 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.011521100997925s - ||Ax-b||/||b||: 9.394574002600326e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1613013744354248 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18850350379943848 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0613040924072266s - ||Ax-b||/||b||: 8.284318194664389e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16016221046447754 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18606853485107422 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0721230506896973s - ||Ax-b||/||b||: 9.723405509563372e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16119837760925293 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18393325805664062 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0455386638641357s - ||Ax-b||/||b||: 9.99446394094078e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1613311767578125 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18566036224365234 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0590641498565674s - ||Ax-b||/||b||: 6.790597498004376e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1605360507965088 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17786645889282227 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0210700035095215s - ||Ax-b||/||b||: 9.786445550463642e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16146373748779297 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18007493019104004 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.042534828186035s - ||Ax-b||/||b||: 7.68093882745445e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16054964065551758 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17226815223693848 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.090956211090088s - ||Ax-b||/||b||: 7.549246233314016e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16088533401489258 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17118453979492188 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.0052454471588135s - ||Ax-b||/||b||: 9.901507277117556e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16084885597229004 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1703331470489502 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.021801471710205s - ||Ax-b||/||b||: 7.348630160769084e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1609339714050293 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1707155704498291 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.1206252574920654s - ||Ax-b||/||b||: 9.123496080699836e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.26671433448791504 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.19884324073791504 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.308227777481079s - ||Ax-b||/||b||: 9.404331445733006e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1606893539428711 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.18023967742919922 seconds.
#
# Starting Conjugate Gradient method
# Finished in 2.09049916267395s - ||Ax-b||/||b||: 9.610154325479033e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16014575958251953 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17595505714416504 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014639616012573242s - ||Ax-b||/||b||: 3.2376761947897165e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16208863258361816 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.19968581199645996 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.01463770866394043s - ||Ax-b||/||b||: 3.181944897518555e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.160125732421875 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17817473411560059 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014888525009155273s - ||Ax-b||/||b||: 3.172362470401132e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16060495376586914 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17752933502197266 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014607667922973633s - ||Ax-b||/||b||: 3.170405341631247e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16009783744812012 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1821742057800293 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014678001403808594s - ||Ax-b||/||b||: 3.1698755416313177e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1603987216949463 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17619800567626953 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014643430709838867s - ||Ax-b||/||b||: 3.1697152574354684e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.15967297554016113 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1776139736175537 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014624595642089844s - ||Ax-b||/||b||: 3.1696728632391277e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16315412521362305 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17818927764892578 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.015514850616455078s - ||Ax-b||/||b||: 3.169685218609541e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1605839729309082 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17879915237426758 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014840126037597656s - ||Ax-b||/||b||: 3.1697637895996093e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16965413093566895 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17956113815307617 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014599800109863281s - ||Ax-b||/||b||: 3.17000533929586e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16009998321533203 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17815375328063965 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014629364013671875s - ||Ax-b||/||b||: 3.1707181880321286e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.15967535972595215 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1789095401763916 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014631032943725586s - ||Ax-b||/||b||: 3.172829430502338e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1610581874847412 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17899775505065918 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014780044555664062s - ||Ax-b||/||b||: 3.1791171324469806e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.15982389450073242 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17782878875732422 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014638662338256836s - ||Ax-b||/||b||: 3.1979326628162657e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16016602516174316 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1790320873260498 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014630317687988281s - ||Ax-b||/||b||: 3.2545927277273615e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.15993213653564453 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17761898040771484 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014908313751220703s - ||Ax-b||/||b||: 3.427613554536045e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16080331802368164 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1790297031402588 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014618396759033203s - ||Ax-b||/||b||: 3.976269647007747e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16034317016601562 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17783665657043457 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.014737606048583984s - ||Ax-b||/||b||: 5.901059496508695e-07
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16094732284545898 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.1739821434020996 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.018323898315429688s - ||Ax-b||/||b||: 2.461273120306484e-09
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16045928001403809 seconds.
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.17271733283996582 seconds.
#
# Starting Conjugate Gradient method
# Finished in 0.01832437515258789s - ||Ax-b||/||b||: 2.833716100147531e-08

# %%
print(E(p0),E(pf))
plt.plot(energy_upper)
plt.title("Evolution of upper level energy")
plt.xlabel("Number of iterations")
plt.ylabel("Energy")
plt.yscale("log")
#plt.savefig("Results/Upper Level/Penalty_strength_V2/med_pen/convergence.png")
# Out:
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.20958614349365234 seconds.
#
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.16445493698120117 seconds.
# 211.1466950913742 96.37969643419477

# %%
plt.plot(alphas)
plt.title("Evolution of alpha")
plt.xlabel("Number of iterations")
plt.ylabel("alpha")
plt.yscale("log")
#plt.savefig("Results/Upper Level/Penalty_strength_V2/med_pen/alpha.png")

# %%
print(pf[-1])
pysap.Image(data=np.reshape(pf[:-1],(n,n))).show()
# Out:
# 1.631004783801487e-07

# %%
P(pf),E(pf),np.sum(pf)
# Out:
# Evaluating E(p)
#
# Starting PDHG
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# Finished in 0.3833134174346924 seconds.
# (88.57234037233735, 96.37969643419477, 664.8393871058267)

# %%
param["pn1"]=pf[-1]
uk,norms,energy,ssims = pdhg(y,pf[:-1],fourier_op,linear_op,param,ground_truth=u0_mat,maxit=200)
# Out:
# Sigma: 31.622776601683793
# Tau: 0.015811388300841896
# 10  iterations:
# Cost: 6.053360392683299e-09
# Norm: 0.03726623080269017
#
# 20  iterations:
# Cost: 5.93755776995473e-09
# Norm: 0.03063690959629649
#
# 30  iterations:
# Cost: 5.855047535233072e-09
# Norm: 0.020885689621044
#
# 40  iterations:
# Cost: 5.79617975672315e-09
# Norm: 0.01780445540232026
#
# 50  iterations:
# Cost: 5.754115749868462e-09
# Norm: 0.014174624589846717
#
# 60  iterations:
# Cost: 5.723998831954826e-09
# Norm: 0.011142514323081191
#
# 70  iterations:
# Cost: 5.7023861186159414e-09
# Norm: 0.009210760466881872
#
# 80  iterations:
# Cost: 5.686835480649728e-09
# Norm: 0.008455720696970736
#
# 90  iterations:
# Cost: 5.675608389815319e-09
# Norm: 0.007373287574116954
#
# 100  iterations:
# Cost: 5.667463151758357e-09
# Norm: 0.005117324719726792
#
# 110  iterations:
# Cost: 5.661519746031038e-09
# Norm: 0.005336885317570168
#
# 120  iterations:
# Cost: 5.657160487590165e-09
# Norm: 0.004569500306472884
#
# 130  iterations:
# Cost: 5.653937721496378e-09
# Norm: 0.003521316556313224
#
# 140  iterations:
# Cost: 5.651532461916819e-09
# Norm: 0.0026804253254690295
#
# 150  iterations:
# Cost: 5.6497186469032035e-09
# Norm: 0.0025065460527144974
#
# 160  iterations:
# Cost: 5.648334919296107e-09
# Norm: 0.0023491425993430338
#
# 170  iterations:
# Cost: 5.6472628016147346e-09
# Norm: 0.002045865575574224
#
# 180  iterations:
# Cost: 5.646422698968658e-09
# Norm: 0.0023148806591450294
#
# 190  iterations:
# Cost: 5.645756391610532e-09
# Norm: 0.0017316423978603543
#
# 200  iterations:
# Cost: 5.645221209063013e-09
# Norm: 0.0018343103056688173
#
# Finished in 1.159132719039917 seconds.

# %%
print(ssim(uk,u0_mat))

plt.figure()
plt.plot(ssims)
plt.title("Evolution of ssim")
plt.show()

plt.figure()
plt.plot(energy)
plt.title("Evolution of energy")
plt.yscale("log")
plt.show()

pysap.Image(data=uk).show()
# Out:
# 0.8866305262643198
